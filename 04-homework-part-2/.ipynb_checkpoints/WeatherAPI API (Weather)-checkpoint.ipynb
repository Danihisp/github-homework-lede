# %% [markdown]
# # WeatherAPI (Weather)
#
# Answer the following questions using [WeatherAPI](http://www.weatherapi.com/). I've added three cells for most questions but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# Be sure to take advantage of both the documentation and the API Explorer!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*
# - *Tip: Remember you only need to import requests once!*

# %%
import requests

# %% [markdown]
# ## 1) Make a request to the Weather API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
# http://api.weatherapi.com/v1/current.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no

url_location = "http://api.weatherapi.com/v1/current.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no"

# %%
response = requests.get(url_location)

# %%
data = response.json()

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
print(data)
# Out:
# {'location': {'name': 'La Paz', 'region': 'La Paz', 'country': 'Bolivia', 'lat': -16.5, 'lon': -68.15, 'tz_id': 'America/La_Paz', 'localtime_epoch': 1655756729, 'localtime': '2022-06-20 16:25'}, 'current': {'last_updated_epoch': 1655756100, 'last_updated': '2022-06-20 16:15', 'temp_c': 12.0, 'temp_f': 53.6, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 19.2, 'wind_kph': 31.0, 'wind_degree': 280, 'wind_dir': 'W', 'pressure_mb': 1034.0, 'pressure_in': 30.53, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 24, 'cloud': 50, 'feelslike_c': 10.6, 'feelslike_f': 51.1, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 3.0, 'gust_mph': 9.2, 'gust_kph': 14.8}}

# %%
data.keys()
# Out:
# dict_keys(['location', 'current'])

# %%
print("the current wind speed:", data['current']['wind_kph'], "km/h")
print("the current wind speed:", data['current']['wind_mph'], "m/h")
# Out:
# the current wind speed: 31.0 km/h
# the current wind speed: 19.2 m/h

# %%
print(data['current'].keys())
# Out:
# dict_keys(['last_updated_epoch', 'last_updated', 'temp_c', 'temp_f', 'is_day', 'condition', 'wind_mph', 'wind_kph', 'wind_degree', 'wind_dir', 'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity', 'cloud', 'feelslike_c', 'feelslike_f', 'vis_km', 'vis_miles', 'uv', 'gust_mph', 'gust_kph'])

# %%
print(data['current']['temp_c'])
# Out:
# 12.0

# %%
difference = data['current']['temp_c'] - data['current']['feelslike_c']

# %%
if data['current']['temp_c'] > data['current']['feelslike_c']:
    print("It feels", difference, "degrees colder")
elif data['current']['temp_c'] < data['current']['feelslike_c']:
    print("It feels", difference, "degrees warmer")
else:
    print("It's the same")
# Out:
# It feels 1.4000000000000004 degrees colder

# %% [markdown]
# ## 3) What is the API endpoint for moon-related information? For the place you decided on above, how much of the moon will be visible tomorrow?
#
# - *Tip: Check the documentation!*
# - *Tip: If you aren't sure what something means, ask in Slack*

# %%
# http://api.weatherapi.com/v1/forecast.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no => {forecast.json?}

# %%
# http://api.weatherapi.com/v1/forecast.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no&days=2

url_moon = "http://api.weatherapi.com/v1/forecast.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no&days=2"

# %%
response = requests.get(url_moon)

data = response.json()

# %%
print(data)
# Out:
# {'location': {'name': 'La Paz', 'region': 'La Paz', 'country': 'Bolivia', 'lat': -16.5, 'lon': -68.15, 'tz_id': 'America/La_Paz', 'localtime_epoch': 1655756745, 'localtime': '2022-06-20 16:25'}, 'current': {'last_updated_epoch': 1655756100, 'last_updated': '2022-06-20 16:15', 'temp_c': 12.0, 'temp_f': 53.6, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 19.2, 'wind_kph': 31.0, 'wind_degree': 280, 'wind_dir': 'W', 'pressure_mb': 1034.0, 'pressure_in': 30.53, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 24, 'cloud': 50, 'feelslike_c': 10.6, 'feelslike_f': 51.1, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 3.0, 'gust_mph': 9.2, 'gust_kph': 14.8}, 'forecast': {'forecastday': [{'date': '2022-06-20', 'date_epoch': 1655683200, 'day': {'maxtemp_c': 11.2, 'maxtemp_f': 52.2, 'mintemp_c': -0.4, 'mintemp_f': 31.3, 'avgtemp_c': 4.8, 'avgtemp_f': 40.6, 'maxwind_mph': 10.3, 'maxwind_kph': 16.6, 'totalprecip_mm':
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
print(data['forecast'])
# Out:
# {'forecastday': [{'date': '2022-06-20', 'date_epoch': 1655683200, 'day': {'maxtemp_c': 11.2, 'maxtemp_f': 52.2, 'mintemp_c': -0.4, 'mintemp_f': 31.3, 'avgtemp_c': 4.8, 'avgtemp_f': 40.6, 'maxwind_mph': 10.3, 'maxwind_kph': 16.6, 'totalprecip_mm': 0.8, 'totalprecip_in': 0.03, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 51.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 84, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 9.0}, 'astro': {'sunrise': '07:00 AM', 'sunset': '06:09 PM', 'moonrise': 'No moonrise', 'moonset': '12:28 PM', 'moon_phase': 'Last Quarter', 'moon_illumination': '48'}, 'hour': [{'time_epoch': 1655697600, 'time': '2022-06-20 00:00', 'temp_c': 1.5, 'temp_f': 34.7, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 2.7, 'wind_kph': 4.3, 'wind_degree': 
# ...

# %%
print(data['forecast']['forecastday'])
# Out:
# [{'date': '2022-06-20', 'date_epoch': 1655683200, 'day': {'maxtemp_c': 11.2, 'maxtemp_f': 52.2, 'mintemp_c': -0.4, 'mintemp_f': 31.3, 'avgtemp_c': 4.8, 'avgtemp_f': 40.6, 'maxwind_mph': 10.3, 'maxwind_kph': 16.6, 'totalprecip_mm': 0.8, 'totalprecip_in': 0.03, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 51.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 84, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 9.0}, 'astro': {'sunrise': '07:00 AM', 'sunset': '06:09 PM', 'moonrise': 'No moonrise', 'moonset': '12:28 PM', 'moon_phase': 'Last Quarter', 'moon_illumination': '48'}, 'hour': [{'time_epoch': 1655697600, 'time': '2022-06-20 00:00', 'temp_c': 1.5, 'temp_f': 34.7, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 2.7, 'wind_kph': 4.3, 'wind_degree': 89, 'wind_dir': 
# ...

# %%
for forecastday in data['forecast']['forecastday']:
    print('----------')
    print(forecastday['date'])
# Out:
# ----------
# 2022-06-20
# ----------
# 2022-06-21

# %%
for forecastday in data['forecast']['forecastday']:
    print('----------------')
    print(forecastday['astro'])
# Out:
# ----------------
# {'sunrise': '07:00 AM', 'sunset': '06:09 PM', 'moonrise': 'No moonrise', 'moonset': '12:28 PM', 'moon_phase': 'Last Quarter', 'moon_illumination': '48'}
# ----------------
# {'sunrise': '07:00 AM', 'sunset': '06:09 PM', 'moonrise': '12:40 AM', 'moonset': '01:06 PM', 'moon_phase': 'Last Quarter', 'moon_illumination': '40'}

# %%
if forecastday['date'] == '2022-06-20':
    print(forecastday['astro'])

# %%
if forecastday['date'] == '2022-06-20':
    print("The moon phase will be", forecastday['astro']['moon_illumination'], "% visible")

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?
#
# - *Tip: When you requested moon data, you probably overwrote your variables! If so, you'll need to make a new request.*

# %%
# http://api.weatherapi.com/v1/forecast.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no&days=1

url_temperature = "http://api.weatherapi.com/v1/forecast.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no&days=1"

# %%
response = requests.get(url_temperature)

data = response.json()

# %%
print(data)
# Out:
# {'location': {'name': 'La Paz', 'region': 'La Paz', 'country': 'Bolivia', 'lat': -16.5, 'lon': -68.15, 'tz_id': 'America/La_Paz', 'localtime_epoch': 1655756764, 'localtime': '2022-06-20 16:26'}, 'current': {'last_updated_epoch': 1655756100, 'last_updated': '2022-06-20 16:15', 'temp_c': 12.0, 'temp_f': 53.6, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 19.2, 'wind_kph': 31.0, 'wind_degree': 280, 'wind_dir': 'W', 'pressure_mb': 1034.0, 'pressure_in': 30.53, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 24, 'cloud': 50, 'feelslike_c': 10.6, 'feelslike_f': 51.1, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 3.0, 'gust_mph': 9.2, 'gust_kph': 14.8}, 'forecast': {'forecastday': [{'date': '2022-06-20', 'date_epoch': 1655683200, 'day': {'maxtemp_c': 11.2, 'maxtemp_f': 52.2, 'mintemp_c': -0.4, 'mintemp_f': 31.3, 'avgtemp_c': 4.8, 'avgtemp_f': 40.6, 'maxwind_mph': 10.3, 'maxwind_kph': 16.6, 'totalprecip_mm':
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
print(data['forecast'].keys())
# Out:
# dict_keys(['forecastday'])

# %%
print(data['forecast']['forecastday'])
# Out:
# [{'date': '2022-06-20', 'date_epoch': 1655683200, 'day': {'maxtemp_c': 11.2, 'maxtemp_f': 52.2, 'mintemp_c': -0.4, 'mintemp_f': 31.3, 'avgtemp_c': 4.8, 'avgtemp_f': 40.6, 'maxwind_mph': 10.3, 'maxwind_kph': 16.6, 'totalprecip_mm': 0.8, 'totalprecip_in': 0.03, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 51.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 84, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 9.0}, 'astro': {'sunrise': '07:00 AM', 'sunset': '06:09 PM', 'moonrise': 'No moonrise', 'moonset': '12:28 PM', 'moon_phase': 'Last Quarter', 'moon_illumination': '48'}, 'hour': [{'time_epoch': 1655697600, 'time': '2022-06-20 00:00', 'temp_c': 1.5, 'temp_f': 34.7, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 2.7, 'wind_kph': 4.3, 'wind_degree': 89, 'wind_dir': 
# ...

# %%
for forecastday in data['forecast']['forecastday']:
    print(forecastday['day'])
# Out:
# {'maxtemp_c': 11.2, 'maxtemp_f': 52.2, 'mintemp_c': -0.4, 'mintemp_f': 31.3, 'avgtemp_c': 4.8, 'avgtemp_f': 40.6, 'maxwind_mph': 10.3, 'maxwind_kph': 16.6, 'totalprecip_mm': 0.8, 'totalprecip_in': 0.03, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 51.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 84, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 9.0}
# {'maxtemp_c': 12.6, 'maxtemp_f': 54.7, 'mintemp_c': 1.1, 'mintemp_f': 34.0, 'avgtemp_c': 5.7, 'avgtemp_f': 42.2, 'maxwind_mph': 13.2, 'maxwind_kph': 21.2, 'totalprecip_mm': 0.0, 'totalprecip_in': 0.0, 'avgvis_km': 10.0, 'avgvis_miles': 6.0, 'avghumidity': 53.0, 'daily_will_it_rain': 0, 'daily_chance_of_rain': 0, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'uv': 9.0}
# ...

# %%
if forecastday['date'] == '2022-06-19':
    print(forecastday['day'])

# %%
if forecastday['date'] == '2022-06-20':
    print(forecastday['day']['maxtemp_c'])
    print(forecastday['day']['mintemp_c'])

# %%
if forecastday['date'] == '2022-06-19':
    print("The difference between the high and low temperatures is", forecastday['day']['maxtemp_c'] - forecastday['day']['mintemp_c'])

# %% [markdown]
# ## 4.5) How can you avoid the "oh no I don't have the data any more because I made another request" problem in the future?
#
# What variable(s) do you have to rename, and what would you rename them?

# %%
# You have to change the url variable by renaming it differently.

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next three days' worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
# http://api.weatherapi.com/v1/forecast.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no&days=3

url_forecast3 = "http://api.weatherapi.com/v1/forecast.json?key=8638716fde1c49239bc21302221706&q=La Paz&aqi=no&days=3"

# %%
response = requests.get(url_forecast3)

data = response.json()

# %%
print(data)
# Out:
# {'location': {'name': 'La Paz', 'region': 'La Paz', 'country': 'Bolivia', 'lat': -16.5, 'lon': -68.15, 'tz_id': 'America/La_Paz', 'localtime_epoch': 1655756791, 'localtime': '2022-06-20 16:26'}, 'current': {'last_updated_epoch': 1655756100, 'last_updated': '2022-06-20 16:15', 'temp_c': 11.2, 'temp_f': 52.2, 'is_day': 1, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 290, 'wind_dir': 'WNW', 'pressure_mb': 1012.0, 'pressure_in': 29.9, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 39, 'cloud': 86, 'feelslike_c': 9.6, 'feelslike_f': 49.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 3.0, 'gust_mph': 9.2, 'gust_kph': 14.8}, 'forecast': {'forecastday': [{'date': '2022-06-20', 'date_epoch': 1655683200, 'day': {'maxtemp_c': 11.2, 'maxtemp_f': 52.2, 'mintemp_c': -0.4, 'mintemp_f': 31.3, 'avgtemp_c': 4.8, 'avgtemp_f': 40.6, 'maxwind_mph': 10.3, 'maxwind_kph': 16.6, 'totalpreci
# ...

# %%
for forecastday in data['forecast']['forecastday']:
    print('----------')
    print(forecastday['date'])
# Out:
# ----------
# 2022-06-20
# ----------
# 2022-06-21
# ----------
# 2022-06-22

# %%
# data['forecast']['forecastday'] is a list of dictionaries

forecast_forecastday = data['forecast']['forecastday']

# %%
for forecastday in forecast_forecastday:
    print(forecastday['day'])
# Out:
# {'maxtemp_c': 11.2, 'maxtemp_f': 52.2, 'mintemp_c': -0.4, 'mintemp_f': 31.3, 'avgtemp_c': 4.8, 'avgtemp_f': 40.6, 'maxwind_mph': 10.3, 'maxwind_kph': 16.6, 'totalprecip_mm': 0.8, 'totalprecip_in': 0.03, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 51.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 84, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 9.0}
# {'maxtemp_c': 12.6, 'maxtemp_f': 54.7, 'mintemp_c': 1.1, 'mintemp_f': 34.0, 'avgtemp_c': 5.7, 'avgtemp_f': 42.2, 'maxwind_mph': 13.2, 'maxwind_kph': 21.2, 'totalprecip_mm': 0.0, 'totalprecip_in': 0.0, 'avgvis_km': 10.0, 'avgvis_miles': 6.0, 'avghumidity': 53.0, 'daily_will_it_rain': 0, 'daily_chance_of_rain': 0, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'uv': 9.0}
# ...

# %%
for forecastday['day'] in forecast_forecastday:
    for maxtemp_c in day.values():
        print(maxtemp_c)

print(forecastday['day'].keys())
# Out:
# 2022-06-22
# 1655856000
# ...

# %%
#for date in forecast_forecastday:
    #print(date[forecast_forecastday['date']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
#       1 for date in forecast_forecastday:
# ----> 2     print(date[forecast_forecastday['date']])
#
# TypeError: list indices must be integers or slices, not str

# %%
#for maxtemp_c in forecast_forecastday['day']['maxtemp_c']:
    #print(maxtemp_c['maxtemp_c'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 for maxtemp_c in forecast_forecastday['day']['maxtemp_c']:
#       2     print(maxtemp_c)
#
# TypeError: list indices must be integers or slices, not str

# %%
#if forecastday['date'] == '2022-06-20':
    #print(forecastday['day']['maxtemp_c'])

# %% [markdown]
# ## 5b) The question above used to be an entire week, but not any more. Try to re-use the code above to print out seven days.
#
# What happens? Can you figure out why it doesn't work?
#
# * *Tip: it has to do with the reason you're using an API key - maybe take a look at the "Air Quality Data" introduction for a hint? If you can't figure it out right now, no worries.*

# %% [markdown]
# ## 6) What will be the hottest day in the next three days? What is the high temperature on that day?

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
# - *Tip: You'll only need one day of forecast*

# %% [markdown]
# ## 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) How much will it cost if you need to use 1,500,000 API calls?
#
# You are only allowed 1,000,000 API calls each month. If you were really bad at this homework or made some awful loops, WeatherAPI might shut down your free access.
#
# * *Tip: this involves looking somewhere that isn't the normal documentation.*

# %% [markdown]
# ## 10) You're too poor to spend more money! What else could you do instead of give them money?
#
# * *Tip: I'm not endorsing being sneaky, but newsrooms and students are both generally poverty-stricken.*

# %%
# make a new subscription.
